# %% [markdown]
# # Introducing Colab
#
# Learn about Google Colab and set up a Google account (if you don't already have one) [here](https://colab.research.google.com/)
#
# You should be able to use the free tier or minimal spend to complete all the projects in the class. I personally signed up for Colab Pro+ and I'm loving it - but it's not required.
#
# To see some of what Colab can do, please follow the link below!
#
# https://colab.research.google.com/drive/1DjcrYDZldAXKJ08x1uYIVCtItoLPk1Wr?usp=sharing

# %%
"""
Hugging Face? What will we use?
1. Hub - Lets us connect to the Hugging Face community (import, login with code etc)
2. Datasets - Lets us load datasets from the Hugging Face community
3. Transformers - Library that provides models and tools to develop LLM applications
4. Peft - Parameter-efficient fine-tuning library
5. TRL - Transformers Reinforcement Learning library
6. Accelerate - Library that provides tools to accelerate training and inference (with multi-GPU, TPU, etc)
"""

# %%
"""
Google Colab?
- Run a jupyter notebook in the cloud with a powerful runtime
- Collaborate with others
- Integrate wit other Google services

- Highend GPU & TPUs (Why are GPUs so important? - We need it while dealing with billions of parameters)
- Rent GPUs on demand
"""

"""
Runtimes?
- CPU based
- Lower spec GPU for free or low-cost (T4; 15GB GPU memory)
- We can pay for higher spec GPUs (A100, 40GB GPU memory)
"""
